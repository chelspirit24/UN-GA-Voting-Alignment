# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2026_02_06_ga_voting.csv')
df
# Out:
# /var/folders/5m/51l7xgkx5wb1pxpq6ly4l65c0000gn/T/ipykernel_71871/720716759.py:1: DtypeWarning: Columns (0: session, 1: vote_note) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2026_02_06_ga_voting.csv')
#         undl_id ms_code                             ms_name ms_vote  \
# 0        507407     AFG                         AFGHANISTAN       Y
# 1        507407     ALB                             ALBANIA       Y
# 2        507407     DZA                             ALGERIA       Y
# 3        507407     AND                             ANDORRA       Y
# 4        507407     AGO                              ANGOLA       X
# ...         ...     ...                                 ...     ...
# 947429  4088513     VEN  VENEZUELA (BOLIVARIAN REPUBLIC OF)       X
# 947430  4088513     VNM                            VIET NAM       Y
# 947431  4088513     YEM                               YEMEN       Y
# 947432  4088513     ZMB                              ZAMBIA       X
# 947433  4088513     ZWE                            ZIMBABWE       Y
#
#               date session   resolution                      draft  \
# 0       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 1       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 2       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 3       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 4       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# ...            ...     ...          ...                        ...
# 947429  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947430  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947431  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947432  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947433  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
#
#        committee_report     meeting  \
# 0                   NaN  A/58/PV.68
# 1                   NaN  A/58/PV.68
# 2                   NaN  A/58/PV.68
# 3                   NaN  A/58/PV.68
# 4                   NaN  A/58/PV.68
# ...                 ...         ...
# 947429              NaN   A/80/PV.3
# 947430              NaN   A/80/PV.3
# 947431              NaN   A/80/PV.3
# 947432              NaN   A/80/PV.3
# 947433              NaN   A/80/PV.3
#
#                                                     title  \
# 0       Special information programme on the question ...
# 1       Special information programme on the question ...
# 2       Special information programme on the question ...
# 3       Special information programme on the question ...
# 4       Special information programme on the question ...
# ...                                                   ...
# 947429  Participation by the State of Palestine during...
# 947430  Participation by the State of Palestine during...
# 947431  Participation by the State of Palestine during...
# 947432  Participation by the State of Palestine during...
# 947433  Participation by the State of Palestine during...
#
#                                              agenda_title  \
# 0                                  Question of Palestine.
# 1                                  Question of Palestine.
# 2                                  Question of Palestine.
# 3                                  Question of Palestine.
# 4                                  Question of Palestine.
# ...                                                   ...
# 947429  Organization of work, adoption of the agenda a...
# 947430  Organization of work, adoption of the agenda a...
# 947431  Organization of work, adoption of the agenda a...
# 947432  Organization of work, adoption of the agenda a...
# 947433  Organization of work, adoption of the agenda a...
#
#                                                  subjects vote_note  \
# 0                                      PALESTINE QUESTION       NaN
# 1                                      PALESTINE QUESTION       NaN
# 2                                      PALESTINE QUESTION       NaN
# 3                                      PALESTINE QUESTION       NaN
# 4                                      PALESTINE QUESTION       NaN
# ...                                                   ...       ...
# 947429  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947430  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947431  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947432  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947433  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
#
#         total_yes  total_no  total_abstentions  total_non_voting  total_ms  \
# 0           159.0       6.0                6.0              20.0     191.0
# 1           159.0       6.0                6.0              20.0     191.0
# 2           159.0       6.0                6.0              20.0     191.0
# 3           159.0       6.0                6.0              20.0     191.0
# 4           159.0       6.0                6.0              20.0     191.0
# ...           ...       ...                ...               ...       ...
# 947429      145.0       5.0                6.0              37.0     193.0
# 947430      145.0       5.0                6.0              37.0     193.0
# 947431      145.0       5.0                6.0              37.0     193.0
# 947432      145.0       5.0                6.0              37.0     193.0
# 947433      145.0       5.0                6.0              37.0     193.0
#
#                                            undl_link
# 0        https://digitallibrary.un.org/record/507407
# 1        https://digitallibrary.un.org/record/507407
# 2        https://digitallibrary.un.org/record/507407
# 3        https://digitallibrary.un.org/record/507407
# 4        https://digitallibrary.un.org/record/507407
# ...                                              ...
# 947429  https://digitallibrary.un.org/record/4088513
# 947430  https://digitallibrary.un.org/record/4088513
# 947431  https://digitallibrary.un.org/record/4088513
# 947432  https://digitallibrary.un.org/record/4088513
# 947433  https://digitallibrary.un.org/record/4088513
#
# [947434 rows x 20 columns]

# %%
keywords = 'military|arms|defen[sc]e|security|weapon|nuclear|intervention|missile|peace'

# %%
df_filtered = df.copy()

mask_title = df_filtered['title'].fillna('').str.contains(keywords, case=False, regex=True)
mask_agenda = df_filtered['agenda_title'].fillna('').str.contains(keywords, case=False, regex=True)
mask_subjects = df_filtered['subjects'].fillna('').str.contains(keywords, case=False, regex=True)

security_df = df_filtered[mask_title | mask_agenda | mask_subjects].copy()
security_df
# Out:
#         undl_id ms_code                             ms_name ms_vote  \
# 191      508005     AFG                         AFGHANISTAN       Y
# 192      508005     ALB                             ALBANIA       Y
# 193      508005     DZA                             ALGERIA       Y
# 194      508005     AND                             ANDORRA       Y
# 195      508005     AGO                              ANGOLA       Y
# ...         ...     ...                                 ...     ...
# 947236  4088074     VEN  VENEZUELA (BOLIVARIAN REPUBLIC OF)       X
# 947237  4088074     VNM                            VIET NAM       Y
# 947238  4088074     YEM                               YEMEN       Y
# 947239  4088074     ZMB                              ZAMBIA       X
# 947240  4088074     ZWE                            ZIMBABWE       Y
#
#               date session    resolution           draft committee_report  \
# 191     2003-12-08      58   A/RES/58/36   A/C.1/58/L.44         A/58/461
# 192     2003-12-08      58   A/RES/58/36   A/C.1/58/L.44         A/58/461
# 193     2003-12-08      58   A/RES/58/36   A/C.1/58/L.44         A/58/461
# 194     2003-12-08      58   A/RES/58/36   A/C.1/58/L.44         A/58/461
# 195     2003-12-08      58   A/RES/58/36   A/C.1/58/L.44         A/58/461
# ...            ...     ...           ...             ...              ...
# 947236  2025-09-12      80  A/DEC/80/506  A/80/L.1/Rev.1              NaN
# 947237  2025-09-12      80  A/DEC/80/506  A/80/L.1/Rev.1              NaN
# 947238  2025-09-12      80  A/DEC/80/506  A/80/L.1/Rev.1              NaN
# 947239  2025-09-12      80  A/DEC/80/506  A/80/L.1/Rev.1              NaN
# 947240  2025-09-12      80  A/DEC/80/506  A/80/L.1/Rev.1              NaN
#
#            meeting                                              title  \
# 191     A/58/PV.71  Prevention of an arms race in outer space : re...
# 192     A/58/PV.71  Prevention of an arms race in outer space : re...
# 193     A/58/PV.71  Prevention of an arms race in outer space : re...
# 194     A/58/PV.71  Prevention of an arms race in outer space : re...
# 195     A/58/PV.71  Prevention of an arms race in outer space : re...
# ...            ...                                                ...
# 947236   A/80/PV.2  Endorsement of the New York Declaration on the...
# 947237   A/80/PV.2  Endorsement of the New York Declaration on the...
# 947238   A/80/PV.2  Endorsement of the New York Declaration on the...
# 947239   A/80/PV.2  Endorsement of the New York Declaration on the...
# 947240   A/80/PV.2  Endorsement of the New York Declaration on the...
#
#                                       agenda_title                subjects  \
# 191     Prevention of an arms race in outer space.  ARMS RACE--OUTER SPACE
# 192     Prevention of an arms race in outer space.  ARMS RACE--OUTER SPACE
# 193     Prevention of an arms race in outer space.  ARMS RACE--OUTER SPACE
# 194     Prevention of an arms race in outer space.  ARMS RACE--OUTER SPACE
# 195     Prevention of an arms race in outer space.  ARMS RACE--OUTER SPACE
# ...                                            ...                     ...
# 947236                      Question of Palestine.      PALESTINE QUESTION
# 947237                      Question of Palestine.      PALESTINE QUESTION
# 947238                      Question of Palestine.      PALESTINE QUESTION
# 947239                      Question of Palestine.      PALESTINE QUESTION
# 947240                      Question of Palestine.      PALESTINE QUESTION
#
#        vote_note  total_yes  total_no  total_abstentions  total_non_voting  \
# 191          NaN      174.0       0.0                4.0              13.0
# 192          NaN      174.0       0.0                4.0              13.0
# 193          NaN      174.0       0.0                4.0              13.0
# 194          NaN      174.0       0.0                4.0              13.0
# 195          NaN      174.0       0.0                4.0              13.0
# ...          ...        ...       ...                ...               ...
# 947236       NaN      142.0      10.0               12.0              29.0
# 947237       NaN      142.0      10.0               12.0              29.0
# 947238       NaN      142.0      10.0               12.0              29.0
# 947239       NaN      142.0      10.0               12.0              29.0
# 947240       NaN      142.0      10.0               12.0              29.0
#
#         total_ms                                     undl_link
# 191        191.0   https://digitallibrary.un.org/record/508005
# 192        191.0   https://digitallibrary.un.org/record/508005
# 193        191.0   https://digitallibrary.un.org/record/508005
# 194        191.0   https://digitallibrary.un.org/record/508005
# 195        191.0   https://digitallibrary.un.org/record/508005
# ...          ...                                           ...
# 947236     193.0  https://digitallibrary.un.org/record/4088074
# 947237     193.0  https://digitallibrary.un.org/record/4088074
# 947238     193.0  https://digitallibrary.un.org/record/4088074
# 947239     193.0  https://digitallibrary.un.org/record/4088074
# 947240     193.0  https://digitallibrary.un.org/record/4088074
#
# [265095 rows x 20 columns]

# %%
votes = security_df[['undl_id', 'date', 'ms_code', 'ms_vote']].drop_duplicates()
vote_pivot = votes.pivot(index=['undl_id', 'date'], columns='ms_code', values='ms_vote').reset_index()
vote_pivot['year'] = pd.to_datetime(vote_pivot['date']).dt.year
vote_pivot = vote_pivot.sort_values('date')
vote_pivot
# Out:
# ms_code  undl_id        date AFG  AGO  ALB  AND  ARE ARG  ARM  ATG  ...  VNM  \
# 1014      671250  1946-12-13   Y  NaN  NaN  NaN  NaN   Y  NaN  NaN  ...  NaN
# 1009      670279  1950-11-03   Y  NaN  NaN  NaN  NaN   A  NaN  NaN  ...  NaN
# 1010      670330  1950-12-01   A  NaN  NaN  NaN  NaN   Y  NaN  NaN  ...  NaN
# 1011      670560  1950-12-14   Y  NaN  NaN  NaN  NaN   Y  NaN  NaN  ...  NaN
# 1013      670655  1951-02-01   A  NaN  NaN  NaN  NaN   Y  NaN  NaN  ...  NaN
# ...          ...         ...  ..  ...  ...  ...  ...  ..  ...  ...  ...  ...
# 1510     4094643  2025-12-03   X    A    Y    Y    A   Y    A    X  ...    A
# 1527     4095075  2025-12-05   X    Y    Y    Y    Y   Y    Y    Y  ...    Y
# 1528     4095321  2025-12-10   X    A    Y    Y    Y   Y    Y    X  ...    Y
# 1529     4095325  2025-12-10   X    Y    Y    Y    Y   X    Y    X  ...    Y
# 1530     4095704  2025-12-15   X    Y    Y    Y    Y   X    Y    Y  ...    Y
#
# ms_code  VUT  WSM  YEM  YMD  YUG ZAF  ZMB  ZWE  year
# 1014     NaN  NaN  NaN  NaN    N   Y  NaN  NaN  1946
# 1009     NaN  NaN    Y  NaN    Y   Y  NaN  NaN  1950
# 1010     NaN  NaN    Y  NaN    N   N  NaN  NaN  1950
# 1011     NaN  NaN    Y  NaN    Y   Y  NaN  NaN  1950
# 1013     NaN  NaN    A  NaN    A   Y  NaN  NaN  1951
# ...      ...  ...  ...  ...  ...  ..  ...  ...   ...
# 1510       Y    X    A  NaN  NaN   Y    X    A  2025
# 1527       Y    Y    Y  NaN  NaN   Y    Y    Y  2025
# 1528       X    Y    A  NaN  NaN   A    X    X  2025
# 1529       Y    Y    Y  NaN  NaN   Y    X    X  2025
# 1530       Y    Y    Y  NaN  NaN   Y    Y    Y  2025
#
# [1531 rows x 205 columns]

# %%
user_input = input("Enter a country name to analyze: ").strip().lower()

unique_countries = df[['ms_name', 'ms_code']].dropna().drop_duplicates()
matches = unique_countries[unique_countries['ms_name'].str.lower().str.contains(user_input, na=False)]

if len(matches) == 0:
    print(f"Could not find any country matching '{user_input}'. Try checking the spelling!")
else:
    target = matches['ms_code'].iloc[0]
    country = matches['ms_name'].iloc[0].title()

# %%
def calculate_alignment(pivot_df, target_country, great_powers):
    results = pivot_df[['undl_id', 'date', 'year']].copy()
    
    for gp in great_powers:
        v1 = pivot_df[target_country]
        v2 = pivot_df[gp]
        
        same = (v1 == v2) & v1.isin(['Y', 'N', 'A'])
        partial = ((v1 == 'A') & v2.isin(['Y', 'N'])) | ((v2 == 'A') & v1.isin(['Y', 'N']))
        opposed = ((v1 == 'Y') & (v2 == 'N')) | ((v1 == 'N') & (v2 == 'Y'))
        
        scores = np.select(
            [same, partial, opposed],
            [1.0, 0.5, 0.0],
            default=np.nan 
        )
        
        results[f'Align_{gp}'] = scores
        
    return results

powers = ['USA', 'CHN', 'SUN', 'RUS']

alignment_df = calculate_alignment(vote_pivot, target, powers)
annual_alignment = alignment_df.groupby('year')[[f'Align_{gp}' for gp in powers]].mean()

# %%
plt.style.use("ggplot") 
colors = {'USA': '#1f77b4', 'CHN': '#d62728', 'SUN': '#2ca02c','RUS': '#0b280b'}

annual_alignment.rename(columns=lambda c: c.split('_')[1]).rolling(3, min_periods=1).mean().plot(
    subplots=True,
    layout=(4, 1),    
    figsize=(12, 14), 
    sharex=False,     
    sharey=False,     
    ylim=(-0.05, 1.05),
    xlim=(annual_alignment.index.min(), annual_alignment.index.max()),
    color=colors,
    linewidth=3
)

plt.suptitle(f"UN General Assembly Voting Alignment on Security & Defense\n{country} vs. Great Powers (1946-2025)", fontsize=16, weight="bold", y=1.00)
plt.tight_layout()
plt.show()
