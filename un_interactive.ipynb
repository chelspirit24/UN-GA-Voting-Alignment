# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2026_02_06_ga_voting.csv')
df
# Out:
# /var/folders/5m/51l7xgkx5wb1pxpq6ly4l65c0000gn/T/ipykernel_52353/720716759.py:1: DtypeWarning: Columns (0: session, 1: vote_note) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2026_02_06_ga_voting.csv')
#         undl_id ms_code                             ms_name ms_vote  \
# 0        507407     AFG                         AFGHANISTAN       Y
# 1        507407     ALB                             ALBANIA       Y
# 2        507407     DZA                             ALGERIA       Y
# 3        507407     AND                             ANDORRA       Y
# 4        507407     AGO                              ANGOLA       X
# ...         ...     ...                                 ...     ...
# 947429  4088513     VEN  VENEZUELA (BOLIVARIAN REPUBLIC OF)       X
# 947430  4088513     VNM                            VIET NAM       Y
# 947431  4088513     YEM                               YEMEN       Y
# 947432  4088513     ZMB                              ZAMBIA       X
# 947433  4088513     ZWE                            ZIMBABWE       Y
#
#               date session   resolution                      draft  \
# 0       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 1       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 2       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 3       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# 4       2003-12-03      58  A/RES/58/20  A/58/L.25|A/58/L.25/Add.1
# ...            ...     ...          ...                        ...
# 947429  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947430  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947431  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947432  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
# 947433  2025-09-19      80   A/RES/80/1             A/80/L.2/Rev.1
#
#        committee_report     meeting  \
# 0                   NaN  A/58/PV.68
# 1                   NaN  A/58/PV.68
# 2                   NaN  A/58/PV.68
# 3                   NaN  A/58/PV.68
# 4                   NaN  A/58/PV.68
# ...                 ...         ...
# 947429              NaN   A/80/PV.3
# 947430              NaN   A/80/PV.3
# 947431              NaN   A/80/PV.3
# 947432              NaN   A/80/PV.3
# 947433              NaN   A/80/PV.3
#
#                                                     title  \
# 0       Special information programme on the question ...
# 1       Special information programme on the question ...
# 2       Special information programme on the question ...
# 3       Special information programme on the question ...
# 4       Special information programme on the question ...
# ...                                                   ...
# 947429  Participation by the State of Palestine during...
# 947430  Participation by the State of Palestine during...
# 947431  Participation by the State of Palestine during...
# 947432  Participation by the State of Palestine during...
# 947433  Participation by the State of Palestine during...
#
#                                              agenda_title  \
# 0                                  Question of Palestine.
# 1                                  Question of Palestine.
# 2                                  Question of Palestine.
# 3                                  Question of Palestine.
# 4                                  Question of Palestine.
# ...                                                   ...
# 947429  Organization of work, adoption of the agenda a...
# 947430  Organization of work, adoption of the agenda a...
# 947431  Organization of work, adoption of the agenda a...
# 947432  Organization of work, adoption of the agenda a...
# 947433  Organization of work, adoption of the agenda a...
#
#                                                  subjects vote_note  \
# 0                                      PALESTINE QUESTION       NaN
# 1                                      PALESTINE QUESTION       NaN
# 2                                      PALESTINE QUESTION       NaN
# 3                                      PALESTINE QUESTION       NaN
# 4                                      PALESTINE QUESTION       NaN
# ...                                                   ...       ...
# 947429  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947430  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947431  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947432  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
# 947433  UN. GENERAL ASSEMBLY (80TH SESS. : 2025-2026)-...       NaN
#
#         total_yes  total_no  total_abstentions  total_non_voting  total_ms  \
# 0           159.0       6.0                6.0              20.0     191.0
# 1           159.0       6.0                6.0              20.0     191.0
# 2           159.0       6.0                6.0              20.0     191.0
# 3           159.0       6.0                6.0              20.0     191.0
# 4           159.0       6.0                6.0              20.0     191.0
# ...           ...       ...                ...               ...       ...
# 947429      145.0       5.0                6.0              37.0     193.0
# 947430      145.0       5.0                6.0              37.0     193.0
# 947431      145.0       5.0                6.0              37.0     193.0
# 947432      145.0       5.0                6.0              37.0     193.0
# 947433      145.0       5.0                6.0              37.0     193.0
#
#                                            undl_link
# 0        https://digitallibrary.un.org/record/507407
# 1        https://digitallibrary.un.org/record/507407
# 2        https://digitallibrary.un.org/record/507407
# 3        https://digitallibrary.un.org/record/507407
# 4        https://digitallibrary.un.org/record/507407
# ...                                              ...
# 947429  https://digitallibrary.un.org/record/4088513
# 947430  https://digitallibrary.un.org/record/4088513
# 947431  https://digitallibrary.un.org/record/4088513
# 947432  https://digitallibrary.un.org/record/4088513
# 947433  https://digitallibrary.un.org/record/4088513
#
# [947434 rows x 20 columns]

# %%
keywords = 'military|arms|defen[sc]e|security|weapon|nuclear|intervention|missile|peace'

# %%
df_filtered = df.copy()

mask_title = df_filtered['title'].fillna('').str.contains(keywords, case=False, regex=True)
mask_agenda = df_filtered['agenda_title'].fillna('').str.contains(keywords, case=False, regex=True)
mask_subjects = df_filtered['subjects'].fillna('').str.contains(keywords, case=False, regex=True)

security_df = df_filtered[mask_title | mask_agenda | mask_subjects].copy()

# %%
votes = security_df[['undl_id', 'date', 'ms_code', 'ms_vote']].drop_duplicates()
vote_pivot = votes.pivot(index=['undl_id', 'date'], columns='ms_code', values='ms_vote').reset_index()
vote_pivot['year'] = pd.to_datetime(vote_pivot['date']).dt.year
vote_pivot = vote_pivot.sort_values('date')

# %%
user_input = input("Enter a country name to analyze: ").strip().lower()

unique_countries = df[['ms_name', 'ms_code']].dropna().drop_duplicates()

matches = unique_countries[unique_countries['ms_name'].str.lower().str.contains(user_input, na=False)]

if len(matches) == 0:
    print(f"Could not find any country matching '{user_input}'. Try checking the spelling!")
    
else:
    target = matches['ms_code'].iloc[0]
    display_name = matches['ms_name'].iloc[0].title()

# %%
def calculate_alignment(pivot_df, target_country, great_powers):
    results = pivot_df[['undl_id', 'date', 'year']].copy()
    
    for gp in great_powers:
        v1 = pivot_df[target_country]
        v2 = pivot_df[gp]
        
        same = (v1 == v2) & v1.isin(['Y', 'N', 'A'])
        partial = ((v1 == 'A') & v2.isin(['Y', 'N'])) | ((v2 == 'A') & v1.isin(['Y', 'N']))
        opposed = ((v1 == 'Y') & (v2 == 'N')) | ((v1 == 'N') & (v2 == 'Y'))
        
        scores = np.select(
            [same, partial, opposed],
            [1.0, 0.5, 0.0],
            default=np.nan 
        )
        
        results[f'Align_{gp}'] = scores
        
    return results

powers = ['USA', 'CHN', 'RUS', 'SUN']

alignment_df = calculate_alignment(vote_pivot, target, powers)
annual_alignment = alignment_df.groupby('year')[[f'Align_{gp}' for gp in powers]].mean()

# %%
window = 3
rolling_alignment = annual_alignment.rolling(window=window, min_periods=1).mean()

plt.style.use('ggplot') 
fig, ax = plt.subplots(figsize=(12, 7))

colors = {'USA': '#1f77b4', 'CHN': '#d62728', 'RUS': '#0b280b', 'SUN' : '#2ca02c'}

for gp in powers:
    ax.plot(rolling_alignment.index, rolling_alignment[f'Align_{gp}'], 
            label=f'{gp} (Rolling {window}yr)', color=colors[gp], linewidth=3)
    

min_year = annual_alignment.index.min()
max_year = annual_alignment.index.max()

ax.set_title(f"UN General Assembly Voting Alignment on Security & Defense\n{display_name} vs. Great Powers ({min_year}-{max_year})", fontsize=16, weight='bold')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Alignment Score (0 = Opposed, 0.5 = Partial, 1.0 = Agree)", fontsize=12)
ax.set_ylim(-0.05, 1.05)

ax.grid(True, which='both', linestyle='--', alpha=0.6)
ax.legend(loc='lower left', fontsize=11, frameon=True, shadow=True)

plt.tight_layout()
plt.show()
